# %%
"""
Dataset for training an NLP model to classify users into Hipster, Hustler, or Hacker archetypes.
Each entry contains a sentence and its corresponding label.
This dataset includes 70 labeled sentences:

50 examples for the HIPSTER archetype
50 examples for the HACKER archetype
50 examples for the HUSTLER archetype
10 examples of mixed or ambiguous characteristics

text: The sentence describing characteristics of an archetype
label: The corresponding label (HIPSTER, HACKER, HUSTLER, or mixed labels)
"""
archetype_dataset = [
    # HIPSTER sentences
    {"text": "The hipster eats, sleeps and breathes design.", "label": "HIPSTER"},
    {"text": "I ensure the final product is cooler than anything else out there.", "label": "HIPSTER"},
    {"text": "I carefully select the shade of blue to accent the font in a way that brings out subtle artistic homages.", "label": "HIPSTER"},
    {"text": "The designer sets best practices in marketing, brand identity building, user experience, and the look and feel of the product.", "label": "HIPSTER"},
    {"text": "I make sure the product is delivering the best customer experience.", "label": "HIPSTER"},
    {"text": "In most early-stage start-ups, I serve as the copywriter as well as the designer.", "label": "HIPSTER"},
    {"text": "I have good taste and a strong creative vision.", "label": "HIPSTER"},
    {"text": "I approach design with empathy and thoughtfulness.", "label": "HIPSTER"},
    {"text": "I prefer minimalist solutions that communicate clearly.", "label": "HIPSTER"},
    {"text": "I'm responsible for the look and feel of our product.", "label": "HIPSTER"},
    {"text": "My design choices are deliberate and meaningful.", "label": "HIPSTER"},
    {"text": "I bring the creative design and cool factor to the team.", "label": "HIPSTER"},
    {"text": "I care deeply about aesthetics and user experience.", "label": "HIPSTER"},
    {"text": "Hipsters are creative individuals with an eye for design.", "label": "HIPSTER"},
    {"text": "I balance form and function in everything I create.", "label": "HIPSTER"},
    {"text": "I'm known for my attention to visual details that others might miss.", "label": "HIPSTER"},
    {"text": "I think about how users will feel when interacting with our product.", "label": "HIPSTER"},
    {"text": "Design isn't just how it looks; it's how it works.", "label": "HIPSTER"},
    {"text": "I create brand identities that resonate with our target audience.", "label": "HIPSTER"},
    {"text": "The visual language of our product is my primary concern.", "label": "HIPSTER"},
    {"text": "I focus on user-centered design to make the experience seamless.", "label": "HIPSTER"},
    {"text": "A hipster values style, originality, and emotional connection in products.", "label": "HIPSTER"},
    {"text": "I sketch wireframes and think about how users will feel at every click.", "label": "HIPSTER"},
    {"text": "My inspiration comes from art, culture, and everyday life.", "label": "HIPSTER"},
    {"text": "Design thinking is second nature to me.", "label": "HIPSTER"},
    {"text": "The visual identity of a brand is just as important as the product itself.", "label": "HIPSTER"},
    {"text": "I'm always experimenting with design tools and new creative techniques.", "label": "HIPSTER"},
    {"text": "A hipster brings emotion and vision to technical products.", "label": "HIPSTER"},
    {"text": "I care deeply about how our app feels in the hands of users.", "label": "HIPSTER"},
    {"text": "Good design can turn a product from useful to unforgettable.", "label": "HIPSTER"},
    {"text": "The design should reflect the personality of the brand.", "label": "HIPSTER"},
    {"text": "Color contrast should be easy on the eyes.", "label": "HIPSTER"},
    {"text": "The user interface needs to be intuitive and clean.", "label": "HIPSTER"},
    {"text": "Good design aligns with the message of the brand.", "label": "HIPSTER"},
    {"text": "The aesthetic should match the target audience’s vibe.", "label": "HIPSTER"},
    {"text": "Creative and design-oriented.", "label": "HIPSTER"},
    {"text": "Focuses on user experience and beauty.", "label": "HIPSTER"},
    {"text": "Prefers minimalism and elegance.", "label": "HIPSTER"},
    {"text": "Values the importance of details and finishing.", "label": "HIPSTER"},
    {"text": "Balances art with function in design.", "label": "HIPSTER"},

    # HACKER sentences
    {"text": "The hacker eats, sleeps and breathes code.", "label": "HACKER"},
    {"text": "I'm the tech person who builds the actual product.", "label": "HACKER"},
    {"text": "I create the algorithms, intellectual property and resulting technology that forms the building blocks of the business.", "label": "HACKER"},
    {"text": "I'm instrumental in choosing the coding environment and platform for the start-up to sustain growth.", "label": "HACKER"},
    {"text": "I answer the all important question of 'how' new ideas can be brought into reality.", "label": "HACKER"},
    {"text": "I resemble MacGyver with my ability to wield various lines of code or programming languages.", "label": "HACKER"},
    {"text": "My keystrokes are fast and efficient when I'm solving problems.", "label": "HACKER"},
    {"text": "I approach problems with analytical thinking.", "label": "HACKER"},
    {"text": "I prefer structured solutions and reliable systems.", "label": "HACKER"},
    {"text": "I stay focused on technical challenges for extended periods.", "label": "HACKER"},
    {"text": "I bring my utility belt of technology solutions to the team.", "label": "HACKER"},
    {"text": "I sit quietly through meetings until I can provide technical solutions.", "label": "HACKER"},
    {"text": "Hackers are analytical people who build technology solutions.", "label": "HACKER"},
    {"text": "I transform ideas into functional code.", "label": "HACKER"},
    {"text": "Technical feasibility is my primary concern when evaluating ideas.", "label": "HACKER"},
    {"text": "I think in terms of systems and how components interact.", "label": "HACKER"},
    {"text": "I'm most comfortable when working with technical challenges.", "label": "HACKER"},
    {"text": "Efficiency and functionality drive my decision making.", "label": "HACKER"},
    {"text": "I evaluate solutions based on their technical merit.", "label": "HACKER"},
    {"text": "Programming languages are tools in my arsenal for solving problems.", "label": "HACKER"},
    {"text": "I built the backend from scratch to ensure it scales under pressure.", "label": "HACKER"},
    {"text": "Hackers are driven by curiosity and the urge to solve technical problems.", "label": "HACKER"},
    {"text": "I debug until 3 AM because I want it to be perfect.", "label": "HACKER"},
    {"text": "I think in algorithms and see the world in logical steps.", "label": "HACKER"},
    {"text": "Code is my canvas, and performance is my obsession.", "label": "HACKER"},
    {"text": "I designed the architecture to support millions of users.", "label": "HACKER"},
    {"text": "Hackers enjoy turning abstract ideas into working systems.", "label": "HACKER"},
    {"text": "I thrive in the silence of deep focus and terminal screens.", "label": "HACKER"},
    {"text": "Every bug I fix teaches me something new.", "label": "HACKER"},
    {"text": "I don't just write code — I engineer reliable systems.", "label": "HACKER"},
    {"text": "The code needs to be clean and organized.", "label": "HACKER"},
    {"text": "Automated testing should be part of the workflow.", "label": "HACKER"},
    {"text": "Error handling must be robust and efficient.", "label": "HACKER"},
    {"text": "The backend must be scalable and flexible.", "label": "HACKER"},
    {"text": "Every system should be optimized for speed.", "label": "HACKER"},
    {"text": "Analytical and problem-solving oriented.", "label": "HACKER"},
    {"text": "Focuses on logic and efficiency.", "label": "HACKER"},
    {"text": "Always looks for technical challenges.", "label": "HACKER"},
    {"text": "Enjoys working with code and technology.", "label": "HACKER"},
    {"text": "Values precision and structure in solutions.", "label": "HACKER"},
  
    # HUSTLER sentences
    {"text": "The hustler eats, sleeps and breathes the business model.", "label": "HUSTLER"},
    {"text": "I'm the business savvy person who makes sure the company makes money.", "label": "HUSTLER"},
    {"text": "I build the team and ignite their passion.", "label": "HUSTLER"},
    {"text": "I manage projects, update the business model, and form partnerships.", "label": "HUSTLER"},
    {"text": "I guide the team along the journey while creating and strengthening its culture.", "label": "HUSTLER"},
    {"text": "I have a keen eye for numbers such as financials, cost structure and user metrics.", "label": "HUSTLER"},
    {"text": "I can speak to the long and short-term vision of the company.", "label": "HUSTLER"},
    {"text": "I make investor pitches and tough decisions.", "label": "HUSTLER"},
    {"text": "I ask if it's something our partners and clients actually want.", "label": "HUSTLER"},
    {"text": "I find the right way to package everything and take it to the masses through sales and partnerships.", "label": "HUSTLER"},
    {"text": "I'm a go-getter with a disciplined approach to business.", "label": "HUSTLER"},
    {"text": "I'm extroverted and enjoy networking opportunities.", "label": "HUSTLER"},
    {"text": "I maintain a growth mindset in all business decisions.", "label": "HUSTLER"},
    {"text": "Hustlers are networkers who build business relationships.", "label": "HUSTLER"},
    {"text": "I'm focused on how we can monetize our product effectively.", "label": "HUSTLER"},
    {"text": "Market potential drives my evaluation of new ideas.", "label": "HUSTLER"},
    {"text": "I identify opportunities for partnerships and business growth.", "label": "HUSTLER"},
    {"text": "My strength is translating product features into market value.", "label": "HUSTLER"},
    {"text": "I'm always thinking about scaling and expanding our business.", "label": "HUSTLER"},
    {"text": "Customer acquisition and retention strategies are my specialty.", "label": "HUSTLER"},
    {"text": "I’m always thinking of new ways to monetize our product.", "label": "HUSTLER"},
    {"text": "Hustlers don’t wait for opportunity — they create it.", "label": "HUSTLER"},
    {"text": "I lead our pitch deck and close deals that move us forward.", "label": "HUSTLER"},
    {"text": "I know our market like the back of my hand.", "label": "HUSTLER"},
    {"text": "I live for the energy of a good sales call.", "label": "HUSTLER"},
    {"text": "My superpower is connecting the right people at the right time.", "label": "HUSTLER"},
    {"text": "I focus on KPIs, traction, and customer validation.", "label": "HUSTLER"},
    {"text": "Hustlers see the big picture and execute fast.", "label": "HUSTLER"},
    {"text": "I'm constantly pushing our vision out into the world.", "label": "HUSTLER"},
    {"text": "If I’m not selling, I’m not breathing.", "label": "HUSTLER"},
    {"text": "The business model needs to be scalable.", "label": "HUSTLER"},
    {"text": "Sales strategy should focus on customer acquisition.", "label": "HUSTLER"},
    {"text": "Networking is key to finding business opportunities.", "label": "HUSTLER"},
    {"text": "Client relationships are crucial for long-term growth.", "label": "HUSTLER"},
    {"text": "Revenue streams should be diversified.", "label": "HUSTLER"},
    {"text": "Strategic and goal-oriented.", "label": "HUSTLER"},
    {"text": "Natural leader who drives business forward.", "label": "HUSTLER"},
    {"text": "Focuses on growth and scaling the business.", "label": "HUSTLER"},
    {"text": "Strong at negotiation and deal-making.", "label": "HUSTLER"},
    {"text": "Has a keen understanding of markets and trends.", "label": "HUSTLER"},

    # Mixed or ambiguous examples. Remove if not needed
    {"text": "I balance technical solutions with user experience considerations.", "label": "HACKER_HIPSTER"},
    {"text": "I focus on both design aesthetics and business objectives.", "label": "HIPSTER_HUSTLER"},
    {"text": "I develop technical solutions that drive business growth.", "label": "HACKER_HUSTLER"},
    {"text": "When the Hipster brings design, the Hacker brings solutions, and the Hustler packages it all up, it's a combination that's tough to beat.", "label": "BALANCED"},
    {"text": "I care about both how our product works and how it looks.", "label": "HACKER_HIPSTER"},
    {"text": "I consider both user needs and business requirements.", "label": "HIPSTER_HUSTLER"},
    {"text": "Technical implementation and market fit are equally important to me.", "label": "HACKER_HUSTLER"},
    {"text": "I translate technical features into compelling selling points.", "label": "HACKER_HUSTLER"},
    {"text": "I design interfaces that are both beautiful and functional.", "label": "HIPSTER_HACKER"},
    {"text": "I create marketing strategies that showcase our product's unique features.", "label": "HUSTLER_HIPSTER"}
]

# %%
print(archetype_dataset)
# Out:
# [{'text': 'The hipster eats, sleeps and breathes design.', 'label': 'HIPSTER'}, {'text': 'I ensure the final product is cooler than anything else out there.', 'label': 'HIPSTER'}, {'text': 'I carefully select the shade of blue to accent the font in a way that brings out subtle artistic homages.', 'label': 'HIPSTER'}, {'text': 'The designer sets best practices in marketing, brand identity building, user experience, and the look and feel of the product.', 'label': 'HIPSTER'}, {'text': 'I make sure the product is delivering the best customer experience.', 'label': 'HIPSTER'}, {'text': 'In most early-stage start-ups, I serve as the copywriter as well as the designer.', 'label': 'HIPSTER'}, {'text': 'I have good taste and a strong creative vision.', 'label': 'HIPSTER'}, {'text': 'I approach design with empathy and thoughtfulness.', 'label': 'HIPSTER'}, {'text': 'I prefer minimalist solutions that communicate clearly.', 'label': 'HIPSTER'}, {'text': "I'm responsible for the look and feel o
# ...

# %%
# Preprocessing. Remove lang unnecessary parts.
import re
import string
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from textblob import TextBlob

# Initialize lemmatizer
lemmatizer = WordNetLemmatizer()

# Preprocessing function
def preprocess_text(text):
    """
    This function preprocesses the input text by performing the following operations:
    
    1. **Lowercasing**: Converts all characters in the text to lowercase to ensure uniformity. 
       This step is crucial for text normalization, as words like "Apple" and "apple" should be treated the same.
    
    2. **Removing Punctuation**: Eliminates all punctuation characters (e.g., commas, periods, question marks) 
       to avoid them interfering with the processing of words. This is done using string translation and the `string.punctuation` module.

    3. **Removing Numbers**: Removes any numerical digits that appear in the text using a regular expression (`\d+`), 
       which matches any sequence of digits. This is helpful if numbers aren't relevant for the task (e.g., in sentiment analysis).

    4. **Removing Extra Whitespace**: Consolidates any consecutive spaces into a single space and strips leading/trailing spaces.
       This is done with a regular expression (`\s+`) to ensure the text is properly spaced and doesn't contain unwanted gaps.

    5. **Removing Stopwords**: Eliminates common words that don't provide much value in analysis, such as "the", "is", "and", etc.
       This is accomplished using a predefined list of stopwords from the `nltk.corpus.stopwords`.

    6. **Lemmatization**: Reduces words to their base form or root word. For example, "running" becomes "run", and "better" becomes "good". 
       This step ensures that similar words are treated as the same, which is particularly useful for tasks like text classification and sentiment analysis.
    
   The function returns the cleaned and preprocessed text as output, which is ready for further analysis or modeling.

    """
    
    # Lowercase the text
    text = text.lower()

    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))

    # Remove numbers
    text = re.sub(r'\d+', '', text)

    # Remove extra whitespace
    text = re.sub(r'\s+', ' ', text).strip()

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    words = text.split()
    words = [word for word in words if word not in stop_words]
    text = ' '.join(words)

    # Lemmatize the text
    words = text.split()
    words = [lemmatizer.lemmatize(word) for word in words]
    text = ' '.join(words)

    return text

# Example usage on the dataset
for entry in archetype_dataset:
    entry['text'] = preprocess_text(entry['text'])

# Preview the result
print(archetype_dataset[:10])
# Out:
# [{'text': 'hipster eats sleep breathes design', 'label': 'HIPSTER'}, {'text': 'ensure final product cooler anything else', 'label': 'HIPSTER'}, {'text': 'carefully select shade blue accent font way brings subtle artistic homage', 'label': 'HIPSTER'}, {'text': 'designer set best practice marketing brand identity building user experience look feel product', 'label': 'HIPSTER'}, {'text': 'make sure product delivering best customer experience', 'label': 'HIPSTER'}, {'text': 'earlystage startup serve copywriter well designer', 'label': 'HIPSTER'}, {'text': 'good taste strong creative vision', 'label': 'HIPSTER'}, {'text': 'approach design empathy thoughtfulness', 'label': 'HIPSTER'}, {'text': 'prefer minimalist solution communicate clearly', 'label': 'HIPSTER'}, {'text': 'im responsible look feel product', 'label': 'HIPSTER'}]
